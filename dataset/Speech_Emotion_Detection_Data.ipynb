# %%
import zipfile

# %%
pwd

# %%
# !mkdir .kaggle

# %%
#!mv kaggle.json to C:/Users/<username>/.kaggle/

# %%
# !kaggle datasets download uwrfkaggler/ravdess-emotional-speech-audio
# Out:
# Dataset URL: https://www.kaggle.com/datasets/uwrfkaggler/ravdess-emotional-speech-audio
# License(s): CC-BY-NC-SA-4.0
# ...
#   0%|          | 0.00/429M [00:00<?, ?B/s]
#   0%|          | 1.00M/429M [00:00<00:53, 8.47MB/s]
#   1%|          | 4.00M/429M [00:00<00:23, 18.8MB/s]
#   2%|1         | 7.00M/429M [00:00<00:19, 22.6MB/s]
#   2%|2         | 10.0M/429M [00:00<00:17, 25.5MB/s]
#   3%|3         | 14.0M/429M [00:00<00:15, 28.7MB/s]
#   4%|4         | 18.0M/429M [00:00<00:13, 32.4MB/s]
#   5%|5         | 22.0M/429M [00:00<00:13, 32.1MB/s]
#   6%|6         | 26.0M/429M [00:00<00:12, 32.7MB/s]
#   7%|6         | 30.0M/429M [00:01<00:12, 32.3MB/s]
#   8%|7         | 34.0M/429M [00:01<00:13, 30.1MB/s]
#   9%|9         | 39.0M/429M [00:01<00:11, 34.4MB/s]
#  10%|#         | 43.0M/429M [00:01<00:12, 33.7MB/s]
#  11%|#         | 47.0M/429M [00:01<00:12, 31.7MB/s]
#  12%|#1        | 51.0M/429M [00:01<00:12, 31.0MB/s]
#  13%|#2        | 54.0M/429M [00:01<00:13, 29.5MB/s]
# ...

# %%
# !kaggle datasets download ejlok1/cremad
# Out:
# Dataset URL: https://www.kaggle.com/datasets/ejlok1/cremad
# License(s): ODC Attribution License (ODC-By)
# ...
#   0%|          | 0.00/451M [00:00<?, ?B/s]
#   0%|          | 1.00M/451M [00:00<03:17, 2.39MB/s]
#   0%|          | 2.00M/451M [00:00<02:21, 3.34MB/s]
#   1%|          | 3.00M/451M [00:00<01:43, 4.56MB/s]
#   1%|          | 4.00M/451M [00:00<01:23, 5.63MB/s]
#   1%|1         | 6.00M/451M [00:01<00:58, 7.95MB/s]
#   2%|1         | 8.00M/451M [00:01<00:48, 9.59MB/s]
#   2%|2         | 10.0M/451M [00:01<00:43, 10.6MB/s]
#   3%|2         | 12.0M/451M [00:01<00:40, 11.5MB/s]
#   3%|3         | 14.0M/451M [00:01<00:36, 12.4MB/s]
#   4%|3         | 16.0M/451M [00:01<00:34, 13.2MB/s]
#   4%|3         | 18.0M/451M [00:01<00:31, 14.3MB/s]
#   4%|4         | 20.0M/451M [00:02<01:21, 5.58MB/s]
#   5%|4         | 22.0M/451M [00:03<01:13, 6.10MB/s]
#   6%|5         | 25.0M/451M [00:03<00:52, 8.54MB/s]
#   6%|5         | 27.0M/451M [00:03<00:44, 9.89MB/s]
# ...

# %%
# !kaggle datasets download ejlok1/toronto-emotional-speech-set-tess
# Out:
# Dataset URL: https://www.kaggle.com/datasets/ejlok1/toronto-emotional-speech-set-tess
# License(s): Attribution-NonCommercial-NoDerivatives 4.0 International (CC BY-NC-ND 4.0)
# ...
#   0%|          | 0.00/428M [00:00<?, ?B/s]
#   0%|          | 1.00M/428M [00:00<02:42, 2.75MB/s]
#   0%|          | 2.00M/428M [00:00<01:49, 4.06MB/s]
#   1%|          | 3.00M/428M [00:00<01:25, 5.18MB/s]
#   1%|          | 4.00M/428M [00:00<01:20, 5.54MB/s]
#   1%|1         | 5.00M/428M [00:00<01:11, 6.22MB/s]
#   1%|1         | 6.00M/428M [00:01<01:04, 6.86MB/s]
#   2%|1         | 7.00M/428M [00:01<01:01, 7.14MB/s]
#   2%|1         | 8.00M/428M [00:01<00:58, 7.47MB/s]
#   2%|2         | 9.00M/428M [00:01<00:57, 7.70MB/s]
#   2%|2         | 10.0M/428M [00:01<00:53, 8.22MB/s]
#   3%|2         | 11.0M/428M [00:01<00:56, 7.73MB/s]
#   3%|2         | 12.0M/428M [00:01<00:54, 7.96MB/s]
#   3%|3         | 13.0M/428M [00:02<00:56, 7.75MB/s]
#   3%|3         | 14.0M/428M [00:02<00:55, 7.75MB/s]
# ...

# %%
# !kaggle datasets download ejlok1/surrey-audiovisual-expressed-emotion-savee
# Out:
# Dataset URL: https://www.kaggle.com/datasets/ejlok1/surrey-audiovisual-expressed-emotion-savee
# License(s): copyright-authors
# ...
#   0%|          | 0.00/107M [00:00<?, ?B/s]
#   1%|          | 1.00M/107M [00:00<00:13, 8.47MB/s]
#   3%|2         | 3.00M/107M [00:00<00:09, 11.7MB/s]
#   5%|4         | 5.00M/107M [00:00<00:08, 12.2MB/s]
#   7%|7         | 8.00M/107M [00:00<00:06, 16.8MB/s]
#   9%|9         | 10.0M/107M [00:00<00:06, 15.2MB/s]
#  11%|#1        | 12.0M/107M [00:00<00:07, 13.3MB/s]
#  13%|#3        | 14.0M/107M [00:01<00:06, 14.6MB/s]
#  15%|#4        | 16.0M/107M [00:01<00:06, 15.2MB/s]
#  17%|#6        | 18.0M/107M [00:01<00:06, 15.5MB/s]
#  19%|#8        | 20.0M/107M [00:01<00:06, 15.2MB/s]
#  20%|##        | 22.0M/107M [00:01<00:05, 16.4MB/s]
#  22%|##2       | 24.0M/107M [00:01<00:05, 17.4MB/s]
#  24%|##4       | 26.0M/107M [00:01<00:05, 15.0MB/s]
#  27%|##6       | 29.0M/107M [00:01<00:04, 17.8MB/s]
#  29%|##8       | 31.0M/107M [00:02<00:04, 17.8MB/s]
# ...

# %%
# !mkdir "C:/Users/<username>/ravdess-emotional-speech-audio"

# %%
# %cd "C:/Users/<username>/ravdess-emotional-speech-audio/"
# Out:
# C:\Users\rroysuj\ravdess-emotional-speech-audio

# %%
with zipfile.ZipFile('C:/Users/<username>/ravdess-emotional-speech-audio.zip', 'r') as zip_ref:
    zip_ref.extractall()

# %%
cd ..

# %%
pwd

# %%
with zipfile.ZipFile('C:/Users/<username>/cremad.zip', 'r') as zip_ref:
    zip_ref.extractall()

# %%
with zipfile.ZipFile('C:/Users/<username>/toronto-emotional-speech-set-tess.zip', 'r') as zip_ref:
    zip_ref.extractall()

# %%
with zipfile.ZipFile('C:/Users/<username>/surrey-audiovisual-expressed-emotion-savee.zip', 'r') as zip_ref:
    zip_ref.extractall()
